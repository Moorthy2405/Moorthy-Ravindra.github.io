# %% [markdown]
# ### 1. Import data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pltx

# %%
df=pd.read_csv('bank1.csv')
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ## 2. Make the data proper to make use of data for analysis
#
# ### A. Identify the Features data types before entering into the analysis

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ### B. Convert the datatypes which are wrongly identified according to the business(domain). Kindly use the User Defined function and loop to convert the data types once.

# %%
df.balance.map(float)
conv= {
    "age": int,"job":str,"marital":str,"education":str,"default":str,"balance":float,"housing":str,"loan":str,"contact":str,
    "day":float,"month":str,"duration":float,"campaign":int,"pdays":int,"previous":int,"poutcome":str,"y":str
}
def data_type_converstion(df,conv):
    for col, data_type in conv.items():
            df[col]=df[col].astype(data_type)
    return df
df1=data_type_converstion(df.copy(),conv)
updated_df=df1.dtypes
print(updated_df)
# Out:
# age            int32
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day          float64
# month         object
# duration     float64
# campaign       int32
# pdays          int32
# previous       int32
# poutcome      object
# y             object
# dtype: object

# %% [markdown]
# ### C.	Find and Remove missing if any. Use visualization to find the missing values or Use general method to find the missing values.

# %%
missing_values=df.isnull().sum()
print('missing values',missing_values)

cleaning=df1.dropna()
cleaning
# Out:
# missing values age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# ...

# %%
cleaning=df1.dropna()
print(cleaning)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# ### D. Find duplicates (if necessary)

# %%
df2 = df1.drop_duplicates(subset=['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','y',])
df2
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# # checkpoint 2

# %% [markdown]
# ### 3. Find the average balance of the customer who belongs to the subscribed customer and non-subscribed customer and also use a related plot to show them in visualization.

# %%
subscribed = df1[df1['y'] == 'yes']['balance'].mean()

non_subscribed = df1[df1['y'] == 'no']['balance'].mean()

labels = ['Subscribed', 'Non-Subscribed']
avg_balances = [subscribed,subscribed]

plt.bar(labels, avg_balances, color=['green', 'orange'])
plt.xlabel('Customer Category')
plt.ylabel('Avg Balance')
plt.title('Average Customer Subscription')
plt.tight_layout()
plt.show()


print("Avg Balance Subscribed:",subscribed)
print("Avg Balance - Non-Subscribed:",non_subscribed)
# Out:
# Avg Balance Subscribed: 1571.9558541266795
# Avg Balance - Non-Subscribed: 1403.21175

# %% [markdown]
# ### 4. Use a pie plot to find the distribution(frequency) of the education. Make sure to add labels and show the percentage of each education distribution.

# %%
df1['education'].value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
xy1=df1['education'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(xy1,labels=xy1.index, autopct='%1.01f%%',startangle=90)
plt.title('Education Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 5. Create a function that should be able to create a new feature(Variable) called season using the month column.

# %%
md1 = {'jun':'Summer','jul':'Summer','aug':'Summer','mar':'Spring','apr':'Spring','may':'Spring',
        'sep':'Autumn','oct':'Autumn','nov':'Autumn','dec':'Winter','jan':'Winter','feb':'Winter'}
def seasons(month):
    df1['season']=df1.month.map(md1)
    return df1
seasons(df1.month)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# ### 6.  Use the count plot with a variable that you created in the above question and also the Y variable to find the class distribution.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df1,x='y',hue='season')
plt.title('Class Distribution by Season')
plt.xlabel('Season')
plt.ylabel('Count')
plt.legend(title='y')

# %% [markdown]
# ### 7. Use the Pdays feature and find does it cause any effect on the subscription of the term using the bar plot.

# %%
sns.barplot(data=df1,x='y',y='pdays',hue=None)
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %%
sns.barplot(x=df.y,y=df.pdays)
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %% [markdown]
# ### 8. Replace the -1 as nan values for the P-days store.

# %%
df1['pdays'] = df1['pdays'].replace(-1, np.nan)
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %%
sns.barplot(data=df1,x='y',y='pdays',hue=None)
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %% [markdown]
# ### 9. Once you are done with question number 8, do the same analysis as question number 7. And observe the difference between question number 7 and question number 9.

# %%
### Using Count PLot
df1['pdays'] = df1['pdays'].replace(np.nan,-1)
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %%
sns.countplot(data=df1[df1['balance'] < 0], x='y',hue=None)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
pivot_table = df1.pivot_table(index='job', values='balance',aggfunc='max')
pivot_table
# Out:
#                balance
# job
# admin.         22171.0
# blue-collar    16353.0
# entrepreneur   42045.0
# housemaid      26965.0
# management     27359.0
# retired        71188.0
# self-employed  16430.0
# services       26394.0
# student        11555.0
# technician     27733.0
# unemployed      9019.0
# unknown         7337.0

# %%
class_0 = df1[df1['y'] == 0]
class_1 = df1[df1['y'] == 1]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(class_0['age'], class_0['balance'], color='blue', label='Class 0', alpha=0.7)
plt.scatter(class_1['age'], class_1['balance'], color='red', label='Class 1', alpha=0.7)
plt.title('Scatter Plot of Age vs. Balance with Class Differentiation')
plt.xlabel('Age')
plt.ylabel('Balance')
plt.legend()
plt.show()
